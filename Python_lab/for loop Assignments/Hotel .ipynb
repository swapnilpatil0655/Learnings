# %%
# Hotel 
def Welcome():
    print("Welcome to the Taj ")
    Menu()
    
def Menu ():
    print("press 1. for Veg")
    print("press 2. for Non-veg")
    print("press 3. for Bill")
    print("press 4. for exit")
    opt=int(input())
    dish(opt)
    
def dish(opt):
    if(opt==1):
        print("Veg Dish name:")
        print("1. for Mix-veg")
        print("2. for Dal")
        print("3. for Rice")
        veg_opt=int(input())
        veg(veg_opt)
        
    elif(opt==2):
        print("Non-veg Dish name :")
        print("1. for Chicken")
        print("2. for Biryani")
        print("3. for Shawarma ")
        non_veg_opt=int(input())
        non_veg(non_veg_opt)
        
def veg(veg_opt):
    if(veg_opt==1):
        print("Mix-veg ........250 ")
        qty=int(input("Enter the total Quantity : "))
        price=int(input("Enter the Price :"))
        print("Mix_veg","qty=",qty,"Price=",price,"=",qty*price)
        Menu()
            
    elif(veg_opt==2):
        print("Dal ..........100 ")
        qty=int(input("Enter the total Quantity : "))
        price=int(input("Enter the Price :"))
        print("Dal","qty=",qty,"Price=",price,"=",qty*price)
        
    elif(veg_opt==2):
        print("Rice ..........150 ")
        qty=int(input("Enter the total Quantity : "))
        price=int(input("Enter the Price :"))
        print("Rice","qty=",qty,"Price=",price,"=",qty*price)
        
def non_veg(non_veg_opt):
    if(non_veg_opt==1):
        print("Chicken......250")
        qty=int(input("Enter the total Quantity : "))
        price=int(input("Enter the Price :"))
        print("Chicken","qty=",qty,"Price= ",price,"=",qty*price)
    
    elif(non_veg_opt==2):
        print("Biryani......350")
        qty=int(input("Enter the total Quantity : "))
        price=int(input("Enter the Price :"))
        print("Chicken","qty=",qty,"Price= ",price,"=",qty*price)
        
    elif(non_veg_opt==2):
        print("shawarma......200")
        qty=int(input("Enter the total Quantity : "))
        price=int(input("Enter the Price :"))
        print("Chicken","qty=",qty,"Price= ",price,"=",qty*price)
        
        
Bill=0
def Bill(qty,price):
    global Bill
    Bill=Bill+(qty*price)
    
Welcome()
# Out:
# Welcome to the Taj
# press 1. for Veg
# press 2. for Non-veg
# press 3. for Bill
# press 4. for exit
# 1
# Veg Dish name:
# 1. for Mix-veg
# 2. for Dal
# 3. for Rice
# 1
# Mix-veg ........250
# Enter the total Quantity : 2
# Enter the Price :250
# Mix_veg qty= 2 Price= 250 = 500
# press 1. for Veg
# press 2. for Non-veg
# press 3. for Bill
# press 4. for exit
# 3

# %%
def welcome():
    print("Welcome to Taj\n")
    menu()

def menu():
    print("Press 1 for veg")
    print("Press 2 for non-veg")
    print("Press 3 for bill")
    print("Press 4 to exit\n")
    opt = int(input())
    if opt == 1:
        veg_menu()
    elif opt == 2:
        non_veg_menu()
    elif opt == 3:
        calculate_bill()
    elif opt == 4:
        print("Thank you for visiting Taj")
    else:
        print("Invalid option")
        menu()

def veg_menu():
    print("Veg dishes")
    print("Press 1 for mix-veg")
    print("Press 2 for dal")
    print("Press 3 for rice\n")
    veg_opt = int(input())
    if veg_opt == 1:
        mix_veg()
    elif veg_opt == 2:
        dal()
    elif veg_opt == 3:
        rice()
    else:
        print("Invalid option")
        veg_menu()

def non_veg_menu():
    print("Non-veg dishes")
    print("Press 1 for chicken")
    print("Press 2 for biryani")
    print("Press 3 for shawarma\n")
    non_veg_opt = int(input())
    if non_veg_opt == 1:
        chicken()
    elif non_veg_opt == 2:
        biryani()
    elif non_veg_opt == 3:
        shawarma()
    else:
        print("Invalid option")
        non_veg_menu()

def mix_veg():
    print("Mix-veg selected")
    qty = int(input("Enter quantity: "))
    price = 50
    total = qty * price
    print("Mix-veg qty =", qty, "price =", price, "Total =", total)
    menu()

def dal():
    print("Dal selected")
    qty = int(input("Enter quantity: "))
    price = 60
    total = qty * price
    print("Dal qty =", qty, "price =", price, "Total =", total)
    menu()

def rice():
    print("Rice selected")
    qty = int(input("Enter quantity: "))
    price = 30
    total = qty * price
    print("Rice qty =", qty, "price =", price, "Total =", total)
    menu()

def chicken():
    print("Chicken selected")
    qty = int(input("Enter quantity: "))
    price = 120
    total = qty * price
    print("Chicken qty =", qty, "price =", price, "Total =", total)
    menu()

def biryani():
    print("Biryani selected")
    qty = int(input("Enter quantity: "))
    price = 150
    total = qty * price
    print("Biryani qty =", qty, "price =", price, "Total =", total)
    menu()

def shawarma():
    print("Shawarma selected")
    qty = int(input("Enter quantity: "))
    price = 80
    total = qty * price
    print("Shawarma qty =", qty, "price =", price, "Total =", total)
    menu()

def calculate_bill():
    total = 0
    print("Enter the number of each dish you ordered")
    qty = int(input("Mix-veg: "))
    total += qty * 4
    50
    qty = int(input("Dal: "))
    total += qty * 60
    qty = int(input("Rice: "))
    total += qty * 30
    print("Your total is: ",total)
  
welcome()

# %%
# A simple Python function

def fun():
    print("Welcome to GFG")

fun()
# Out:
# Welcome to GFG

# %%
#Hotel
def welcome ():
    print("Welcome to the Hotel Orian ")
    menu()    
def menu():
    print("Press 1 for Veg ")
    print("Press 2 for Non-veg ")

    opt=int(input("Enter option "))
    if opt==1:
        veg()
def veg():
    print("Veg Thali ...... 60")
    
    else:
        Non_veg()
        
def Non_veg():
    print("Non-veg Thali......100")
    
welcome()
# Out:
#   File "C:\Users\swapn\AppData\Local\Temp\ipykernel_5116\562994060.py", line 15
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
def welcome():
    print("Welcome to the Hotel")
    menu()
    
def menu():
    print("press 1 for veg ")
    print("press 2 for non-veg ")
    print("press 3 for Total bill ")
    opt=int(input("Enter opton : "))
    if(opt==1):
        veg()
    elif(opt==2):
        non_veg()
    elif(opt==3):
        bill()
    
def veg():
    print("press 1 for Dal............. 50 ")
    print("press 2 for Rice........... 100")
    print("press 3 for Roti............ 20  / per pic")
    print("press 4 for Mix-veg........ 250")
    print("press 5 for menu ")
    opt=int(input("Enter option : "))
    if(opt==1):
        dal()
    elif(opt==2):
        rice()
    elif(opt==3):
        roti()
    elif(opt==4):
        mix_veg()
    elif(opt==5):
        menu()
        
def dal():
    p=50
    print("Dal price : 50 ")
    q=int(input("Quantity :  "))
    global total
    total=q*p
    print("Dal ...",q ,"x",p ,"=",total)
    veg()
    
def rice():
    p=100
    print("Rice price : 100 ")
    q=int(input("Quantity :  "))
    global total
    total=q*p
    print("Rice ...",q ,"x",p ,"=",total)
    veg()
    
def roti():
    p=20
    print("Roti price : 20 /per pic ")
    q=int(input("Quantity :  "))
    global total
    total=q*p
    print("Roti ...",q ,"x",p ,"=",total)
    veg()
    
def mix_veg():
    p=250
    print("Mix-veg price : 250 ")
    q=int(input("Quantity :  "))
    global total
    total=q*p
    print("Mix-veg ...",q ,"x",p ,"=",total)
    veg()
    
total=0
s=0
def bill():
    
    global total
    
    s=s+total
    print("Your total bill is",s)
    
    
welcome()
# Out:
# Welcome to the Hotel
# press 1 for veg
# press 2 for non-veg
# press 3 for Total bill
# Enter opton : 1
# press 1 for Dal............. 50
# press 2 for Rice........... 100
# press 3 for Roti............ 20  / per pic
# press 4 for Mix-veg........ 250
# press 5 for menu
# Enter option : 1
# Dal price : 50
# Quantity :  2
# Dal ... 2 x 50 = 100
# press 1 for Dal............. 50
# press 2 for Rice........... 100
# press 3 for Roti............ 20  / per pic
# press 4 for Mix-veg........ 250
# press 5 for menu
# Enter option : 2
# Rice price : 100
# Quantity :  2
# Rice ... 2 x 100 = 200
# press 1 for Dal............. 50
# press 2 for Rice........... 100
# press 3 for Roti............ 20  / per pic
# press 4 for Mix-veg........ 250
# press 5 for menu
# Enter option : 5
# press 1 for veg
# press 2 for non-veg
# press 3 for Total bill
# Enter opton : 3
# Your total bill is 200

# %%
def welcome():
    print("welcome to the Hotel Paradise")
    menu()
def menu():
    flag=True
    while flag:
        print("opt 1 for veg")
        print("opt 2 for nonveg")
        print("opt 3 for desert")
        print("opt 4 for bill")
        print("opt 5 for exit")
        opt= int(input())
        dish(opt)
def dish(opt):
    if(opt==1):
        print("veg food")
        print("1.for mix-veg")
        print("2.for chapati")
        print("3.for rice")
        print("4.for dal tadka")
        veg_opt=int(input())
        veg(veg_opt)
    elif(opt==2):
        print("nonveg food")
        print("1.for butter chicken")
        print("2.for mutton handi")
        print("3.for mutton biryani")
        print("4.for chicken biryani")
        nonveg_opt=int(input())
        nonveg(nonveg_opt)
    elif(opt==3):
        print("desert")
        print("1.for gulabjamun")
        print("2.for ice-cream")
        print("3.for rasmalai")
        print("4.for bengali meethai")
        desert_opt=int(input())
        desert(desert_opt)
    elif(opt==4):
        updtbill(quantity,price)
    elif(opt==5):
        print("Exit")
        final_bill(bill)
        flag=False
def veg(veg_opt):
    if(veg_opt==1):
        print("mix-veg--------Rs.250")
        quantity=int(input("enter the quantity"))
        price=int(input())
        print("mix-veg","quantity=",quantity,"price=",price,"=",quantity*price)
        updtbill(quantity,price)
    elif(veg_opt==2):
        print("chapati--------Rs.100")
        quantity=int(input("enter the quantity"))
        price=int(input())
        print("chapati","quantity=",quantity,"price=",price,"=",quantity*price)
        updtbill(quantity,price)
    elif(veg_opt==3):
        print("rice--------Rs.70")
        quantity=int(input("enter the quantity"))
        price=int(input())
        print("rice","quantity=",quantity,"price=",price,"=",quantity*price) 
        updtbill(quantity,price)
    elif(veg_opt==4):
        print("dal tadka--------Rs.100")
        quantity=int(input("enter the quantity"))
        price=int(input())
        print("dal tadka","quantity=",quantity,"price=",price,"=",quantity*price)
        updtbill(quantity,price)
def nonveg(nonveg_opt):
    if(nonveg_opt==1):
        print("butter chicken--------Rs.350")
        quantity=int(input("enter the quantity"))
        price=int(input())
        print("butter chichen","quantity=",quantity,"price=",price,"=",quantity*price)    
    elif(nonveg_opt==2):
        print("mutton handi--------Rs.450")
        quantity=int(input("enter the quantity"))
        price=int(input())
        print("mutton handi","quantity=",quantity,"price=",price,"=",quantity*price)
    elif(nonveg_opt==3):
        print("mutton biryani--------Rs.400")
        quantity=int(input("enter the quantity"))
        price=int(input())
        print("mutton biryani","quantity=",quantity,"price=",price,"=",quantity*price)
    elif(nonveg_opt==4):
        print("chicken biryani--------Rs.300")
        quantity=int(input("enter the quantity"))
        price=int(input())
        print("ckicken biryani","quantity=",quantity,"price=",price,"=",quantity*price) 
def desert(desert_opt):
    if(desert_opt==1):
        print("gulabjamun--------Rs.20")
        quantity=int(input("enter the quantity"))
        price=int(input())
        print("gulabjamun","quantity=",quantity,"price=",price,"=",quantity*price)    
        updtbill(quantity,price)
    elif(desert_opt==2):
        print("ice-cream--------Rs.60")
        quantity=int(input("enter the quantity"))
        price=int(input())
        print("ice-cream","quantity=",quantity,"price=",price,"=",quantity*price)
        updtbill(quantity,price)
    elif(desert_opt==3):
        print("rasmalai--------Rs.40")
        quantity=int(input("enter the quantity"))
        price=int(input())
        print("rasmalai","quantity=",quantity,"price=",price,"=",quantity*price)
        updtbill(quantity,price)
    elif(desert_opt==4):
        print("bengali meethai--------Rs.50")
        quantity=int(input("enter the quantity"))
        price=int(input())
        print("bengalli meethai","quantity=",quantity,"price=",price,"=",quantity*price) 
        updtbill(quantity,price)
                        
bill=0
def updtbill(quantity,price):
    global bill
    bill =bill + (quantity*price)
    print("update bill",bill)
    
def final_bill(bill):
    print("your final bill is",bill)
    print("Thank you for visiting")
    
welcome()
# Out:
# welcome to the Hotel Paradise
# opt 1 for veg
# opt 2 for nonveg
# opt 3 for desert
# opt 4 for bill
# opt 5 for exit
# 4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4688\1511073201.py in <module>
#     125     print("Thank you for visiting")
#     126
# --> 127 welcome()
#
# ~\AppData\Local\Temp\ipykernel_4688\1511073201.py in welcome()
#       1 def welcome():
#       2     print("welcome to the Hotel Paradise")
# ----> 3     menu()
#       4 def menu():
#       5     flag=True
#
# ~\AppData\Local\Temp\ipykernel_4688\1511073201.py in menu()
#      11         print("opt 5 for exit")
#      12         opt= int(input())
# ---> 13         dish(opt)
#      14 def dish(opt):
#      15     if(opt==1):
#
# ~\AppData\Local\Temp\ipykernel_4688\1511073201.py in dish(opt)
#      38         desert(desert_opt)
#      39     elif(opt==4):
# ...
