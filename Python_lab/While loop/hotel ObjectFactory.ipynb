# %%
#Hotel

# %%
class total ():
    def settotal(self,tp):
        print(tp)

class veg_menu():
    p=100
    tp=0
    def dal(self,vopt,q):
        self.tp=self.p*q
        print("dal...",self.p," x ",q," = ",self.tp,"Rs")
        obj.getveg().setveg()
    
    def rice(self,vopt,q):
        self.tp=self.p*q
        print("rice ...",self.p," x ",q," = ",self.tp,"Rs")
        obj.gettotal().settotal(self.tp)
        
    

class veg():
    def setveg(self):
        print("press 1 for dal")
        print("press 2 for rice")
        print("press 3 for sabji")
        print("press 4 for back")
        print("press 5 for Total")
        vopt=int(input("Enter the option : "))
        if vopt==1:
            print("dal ..........    100 Rs       1Q")
            q=int(input("Enter quantity "))
            obj.getveg_menu().dal(vopt,q)
            
        elif vopt==2:
            print("rice...........   150 Rs        1Q")
            q=int(input("Enter quantity "))
            obj.getveg_menu().rice(vopt,q)
            
        elif vopt==3:
            print("sabji...........  150 Rs        1Q")
            q=int(input("Enter quantity "))
            obj.getveg_menu().rice(vopt,q)
            
        elif vopt==4:
            obj.getmenu().setmenu()
            
       # elif for vopt==5:
      #      obj.gettotal().settotal()
class menu():
    def setmenu(self):
        print("press 1 for veg ")
        print("press 2 for non-veg")
        print("press 3 for bill ")
        print("press 4 for exit ")
        opt=int(input("Enter your option "))
        if opt==1:
            obj.getveg().setveg()
            

class welcome():
    def setwelcome(self):
        print("Welcome to the Hotel ")
        obj.getmenu().setmenu()
        
class ObjectFactory():
    w=welcome()
    m=menu()
    v=veg()
    vm=veg_menu()
    t=total()
    def gettotal(self):
        return self.t
    def getveg_menu(self):
        return self.vm
    def getveg(self):
        return self.v
    def getmenu(self):
        return self.m
    def getwelcome(self):
        return self.w
    
obj=ObjectFactory()
x=obj.getwelcome().setwelcome()
# Out:
# Welcome to the Hotel
# press 1 for veg
# press 2 for non-veg
# press 3 for bill
# press 4 for exit
# Enter your option 1
# press 1 for dal
# press 2 for rice
# press 3 for sabji
# press 4 for back
# press 5 for Total
# Enter the option : 1
# dal ..........    100 Rs       1Q
# Enter quantity 2
# dal... 100  x  2  =  200 Rs
# press 1 for dal
# press 2 for rice
# press 3 for sabji
# press 4 for back
# press 5 for Total
# Enter the option : 2
# rice...........   150 Rs        1Q
# Enter quantity 3
# rice ... 100  x  3  =  300 Rs
# 300
