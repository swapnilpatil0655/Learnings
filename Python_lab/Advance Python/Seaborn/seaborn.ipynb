# %% [markdown]
# # Visualizing statistical relationships
# Statistical analysis is a process of understanding how variables in a dataset relate to each other and how those relationships depend on other variables. Visualization can be a core component of this process because, when data are visualized properly, the human visual system can see trends and patterns that indicate a relationshi

# %% [markdown]
# Seaborn is a python library for data visualization build on top of the matplotlib python library
# plots in seaborn
# 1)Heatmap
# pairplot
# Facet grid plot
# bar plot
# scatterplot
# line plot
# distplot
# boxplot
# Violine plot

# %%
#pip install seaborn
#conda install seaborn-

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %% [markdown]
# # Corellation with heatmap

# %% [markdown]
#  Correlation heatmaps are a type of plot that visualize the strength of relationships between numerical variables. Correlation plots are used to understand which variables are related to each other and the strength of this relationship

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # join plot
# a join plot allows to study the relationship between 2 numeric variables

# %%
# for using univariate analysis
sns.jointplot(x="tip", y="total_bill", data= tips, kind="hex")

# %%
sns.jointplot(x="tip", y="total_bill", data= tips, kind="reg")

# %% [markdown]
# # Pair plot
# A psir plot is also know as a scatterplot, in which, one variable in the same data row is matched with another variables
# value, like this, pair plots are just elaborations on this showing all variables paired with all the other variables.

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue="sex")

# %%
#tips["smoker"].value_count()
sns.pairplot(tips, hue="smoker")

# %% [markdown]
# # Dist plot
# Disht plot helps us to check the distribution of the columns feature

# %%
sns.distplot(tips["total_bill"])
# Out:
# C:\Users\LENOVO\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips["tip"],kde=False, bins=10) # kde kernal density estimation
# Out:
# <AxesSubplot:xlabel='tip'>

# %% [markdown]
# # Categorical plot
# seaborn alsohelps us in doing the analysis on Cateforical Data points, in this section we will discuss.
#
# boxlpot
# violinplot
# countplot
# bar plot

# %%
sns.countplot("sex", data=tips) # bydefault it taking x axis
# Out:
# C:\Users\LENOVO\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot("day", data=tips)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.countplot(x="sex", data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
# bar plot
sns.barplot(x="sex", y="total_bill", data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
# Box plot
sns.boxplot("sex", "total_bill", data=tips)
# Out:
# C:\Users\LENOVO\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(x="day",y= "total_bill", data=tips, palette="rainbow")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips, orient="v")
# Out:
# <AxesSubplot:>

# %%
# categorize my data based on some other categories
sns.boxplot(x="total_bill", y="day", hue="smoker", data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
# Violine plot
sns.violinplot(x="total_bill", y="day", data=tips, palette= "rainbow")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
import seaborn as sns
sns.set_theme(style="white")

# Load the example mpg dataset
mpg = sns.load_dataset("mpg")

# Plot miles per gallon against horsepower with other semantics
sns.relplot(x="horsepower", y="mpg", hue="origin", size="weight",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data=mpg)

# %%
import seaborn as sns
sns.set_theme(style="ticks")

df = sns.load_dataset("penguins")
sns.pairplot(df, hue="species")

# %%
#Scatterplot with categorical variables
import seaborn as sns
sns.set_theme(style="whitegrid", palette="muted")

# Load the penguins dataset
df = sns.load_dataset("penguins")

# Draw a categorical scatterplot to show each observation
ax = sns.swarmplot(data=df, x="body_mass_g", y="sex", hue="species")
ax.set(ylabel="")
# Out:
# [Text(0, 0.5, '')]
