# %%
import pandas as pd

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data = pd.read_csv("Shippers.csv")

# %%
data
# Out:
#    ShipperID       ShipperName           Phone
# 0          1    Speedy Express  (503) 555-9831
# 1          2    United Package  (503) 555-3199
# 2          3  Federal Shipping  (503) 555-9931

# %%
data [["ShipperID","ShipperName"]]
# Out:
#    ShipperID       ShipperName
# 0          1    Speedy Express
# 1          2    United Package
# 2          3  Federal Shipping

# %%
data.tail(10)
data.head()
# Out:
#    ShipperID       ShipperName           Phone
# 0          1    Speedy Express  (503) 555-9831
# 1          2    United Package  (503) 555-3199
# 2          3  Federal Shipping  (503) 555-9931

# %%
data.isnull().sum()
# Out:
# ShipperID      0
# ShipperName    0
# Phone          0
# dtype: int64

# %%
data.describe()
# Out:
#        ShipperID
# count        3.0
# mean         2.0
# std          1.0
# min          1.0
# 25%          1.5
# 50%          2.0
# 75%          2.5
# max          3.0

# %%
data = pd.read_csv("Orders.csv")

# %%
data
# Out:
#      OrderID  CustomerID  EmployeeID   OrderDate  ShipperID
# 0      10248          90           5  1996-07-04          3
# 1      10249          81           6  1996-07-05          1
# 2      10250          34           4  1996-07-08          2
# 3      10251          84           3  1996-07-08          1
# 4      10252          76           4  1996-07-09          2
# ..       ...         ...         ...         ...        ...
# 191    10439          51           6  1997-02-07          3
# 192    10440          71           4  1997-02-10          2
# 193    10441          55           3  1997-02-10          2
# 194    10442          20           3  1997-02-11          2
# 195    10443          66           8  1997-02-12          1
#
# [196 rows x 5 columns]

# %%
data.describe()
# Out:
#            OrderID  CustomerID  EmployeeID   ShipperID
# count    196.00000  196.000000  196.000000  196.000000
# mean   10345.50000   48.647959    4.352041    2.071429
# std       56.72448   25.621777    2.416513    0.787726
# min    10248.00000    2.000000    1.000000    1.000000
# 25%    10296.75000   25.000000    2.750000    1.000000
# 50%    10345.50000   51.000000    4.000000    2.000000
# 75%    10394.25000   69.250000    6.000000    3.000000
# max    10443.00000   91.000000    9.000000    3.000000

# %%
data.tail(0)
data.head(10)
# Out:
#    OrderID  CustomerID  EmployeeID   OrderDate  ShipperID
# 0    10248          90           5  1996-07-04          3
# 1    10249          81           6  1996-07-05          1
# 2    10250          34           4  1996-07-08          2
# 3    10251          84           3  1996-07-08          1
# 4    10252          76           4  1996-07-09          2

# %%
data.isnull().sum()
# Out:
# OrderID       0
# CustomerID    0
# EmployeeID    0
# OrderDate     0
# ShipperID     0
# dtype: int64
