# %%
def sample():
    print("Hello World")
sample()
# Out:
# Hello World

# %%
def add (a,b):
    ans=a+b
    return ans
add(10,20)
ans=add(10,20)

def division (ans): 
    ans1=ans/2
    return ans1
ans1=division(ans)
print(ans)
print(ans1)
# Out:
# 30
# 15.0

# %%
# Add / Division / Print
def add (x,y):
    ans=x+y
    division(ans)
add(10,20)
ans=add(10,20) 
    
def division(ans):
    res=ans/2
    dis(res)
    
def dis(res):
    print(res)
dis()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15640\1506668575.py in <module>
#       3     ans=x+y
#       4     division(ans)
# ----> 5 add(10,20)
#       6 ans=add(10,20)
#       7
#
# ~\AppData\Local\Temp\ipykernel_15640\1506668575.py in add(x, y)
#       2 def add (x,y):
#       3     ans=x+y
# ----> 4     division(ans)
#       5 add(10,20)
#       6 ans=add(10,20)
#
# NameError: name 'division' is not defined

# %%
# Hotel 
def Welcome():
    print("Welcome to the Taj ")
    Menu()
    

    
def Menu ():
    flag=True
    while flag:
        print("press 1. for Veg")
        print("press 2. for Non-veg")
        print("press 3. for Bill")
        print("press4. for exit")
        opt=int(input())
        dish(opt)
    
def dish(opt):
    if(opt==1):
        print("Veg Dish name:")
        print("1. for Mix-veg")
        print("2. for Dal")
        print("3. for Rice")
        veg_opt=int(input())
        veg(veg_opt)
        
    elif(opt==2):
        print("Non-veg Dish name :")
        print("1. for Chicken")
        print("2. for Biryani")
        print("3. for Shawarma ")
        non_veg_opt=int(input())
        non_veg(non_veg_opt)
        
    elif (opt==3):
        Update_Bill(qty,price)
    
    elif (opt==4):
        exit()
        
def veg(veg_opt):
    if(veg_opt==1):
        print("Mix-veg ........250 ")
        qty=int(input("Enter the total Quantity : "))
        price=int(input("Enter the Price :"))
        print("Mix_veg","qty=",qty,"Price=",price,"=",qty*price)
        Update_Bill(qty,price)
            
    elif(veg_opt==2):
        print("Dal ..........100 ")
        qty=int(input("Enter the total Quantity : "))
        price=int(input("Enter the Price :"))
        print("Dal","qty=",qty,"Price=",price,"=",qty*price)
        Update_Bill(qty,price)
        
    elif(veg_opt==2):
        print("Rice ..........150 ")
        qty=int(input("Enter the total Quantity : "))
        price=int(input("Enter the Price :"))
        print("Rice","qty=",qty,"Price=",price,"=",qty*price)
        Update_Bill(qty,price)
        
def non_veg(non_veg_opt):
    if(non_veg_opt==1):
        print("Chicken......250")
        qty=int(input("Enter the total Quantity : "))
        price=int(input("Enter the Price :"))
        print("Chicken","qty=",qty,"Price= ",price,"=",qty*price)
        Update_Bill(qty,price)
    
    elif(non_veg_opt==2):
        print("Biryani......350")
        qty=int(input("Enter the total Quantity : "))
        price=int(input("Enter the Price :"))
        print("Chicken","qty=",qty,"Price= ",price,"=",qty*price)
        Update_Bill(qty,price)
        
    elif(non_veg_opt==2):
        print("shawarma......200")
        qty=int(input("Enter the total Quantity : "))
        price=int(input("Enter the Price :"))
        print("Chicken","qty=",qty,"Price= ",price,"=",qty*price)
        Update_Bill(qty,price)
        
        
Bill=0
def Update_Bill(qty,price):
    global Bill
    Bill=Bill+(qty*price)
    final_Bill()
    
def final_Bill():
    print("Final Bill",Bill)
    exit()
    
def exit():
    print("Thanks for visiting....")
    flag=False
    
Welcome()
# Out:
# Welcome to the Taj
# press 1. for Veg
# press 2. for Non-veg
# press 3. for Bill
# press4. for exit
# 1
# Veg Dish name:
# 1. for Mix-veg
# 2. for Dal
# 3. for Rice
# 1
# Mix-veg ........250
# Enter the total Quantity : 2
# Enter the Price :2
# Mix_veg qty= 2 Price= 2 = 4
# Final Bill 4
# Thanks for visiting....
# press 1. for Veg
# press 2. for Non-veg
# press 3. for Bill
# press4. for exit
# 4
# Thanks for visiting....
# press 1. for Veg
# press 2. for Non-veg
# press 3. for Bill
# press4. for exit
# 4
# Thanks for visiting....
# press 1. for Veg
# press 2. for Non-veg
# press 3. for Bill
# press4. for exit
# 1
# Veg Dish name:
# 1. for Mix-veg
# 2. for Dal
# 3. for Rice
# 1
# Mix-veg ........250
# Enter the total Quantity : 252
# Enter the Price :25
# Mix_veg qty= 252 Price= 25 = 6300
# Final Bill 6304
# Thanks for visiting....
# press 1. for Veg
# press 2. for Non-veg
# press 3. for Bill
# press4. for exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5020\776225627.py in <module>
#      98     flag=False
#      99
# --> 100 Welcome()
#     101
#
# ~\AppData\Local\Temp\ipykernel_5020\776225627.py in Welcome()
#       2 def Welcome():
#       3     print("Welcome to the Taj ")
# ----> 4     Menu()
#       5
#       6
#
# ~\AppData\Local\Temp\ipykernel_5020\776225627.py in Menu()
#      13         print("press 3. for Bill")
#      14         print("press4. for exit")
# ---> 15         opt=int(input())
#      16         dish(opt)
#      17
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# Hotel 
def Welcome():
    print("Welcome to the Taj ")
    Menu()
    
def Menu ():
    print("press 1. for Veg")
    print("press 2. for Non-veg")
    print("press 3. for Bill")
    print("press4. for exit")
    opt=int(input())
    dish(opt)
    
def dish(opt):
    if(opt==1):
        print("Veg Dish name:")
        print("1. for Mix-veg")
        print("2. for Dal")
        print("3. for Rice")
        veg_opt=int(input())
        veg(veg_opt)
        
    elif(opt==2):
        print("Non-veg Dish name :")
        print("1. for Chicken")
        print("2. for Biryani")
        print("3. for Shawarma ")
        non_veg_opt=int(input())
        non_veg(non_veg_opt)
        
def veg(veg_opt):
    if(veg_opt==1):
        print("Mix-veg ........250 ")
        qty=int(input("Enter the total Quantity : "))
        price=int(input("Enter the Price :"))
        print("Mix_veg","qty=",qty,"Price=",price,"=",qty*price)
        Bill(qty,price)
        Menu()
            
    elif(veg_opt==2):
        print("Dal ..........100 ")
        qty=int(input("Enter the total Quantity : "))
        price=int(input("Enter the Price :"))
        print("Dal","qty=",qty,"Price=",price,"=",qty*price)
        
    elif(veg_opt==2):
        print("Rice ..........150 ")
        qty=int(input("Enter the total Quantity : "))
        price=int(input("Enter the Price :"))
        print("Rice","qty=",qty,"Price=",price,"=",qty*price)
        
def non_veg(non_veg_opt):
    if(non_veg_opt==1):
        print("Chicken......250")
        qty=int(input("Enter the total Quantity : "))
        price=int(input("Enter the Price :"))
        print("Chicken","qty=",qty,"Price= ",price,"=",qty*price)
    
    elif(non_veg_opt==2):
        print("Biryani......350")
        qty=int(input("Enter the total Quantity : "))
        price=int(input("Enter the Price :"))
        print("Chicken","qty=",qty,"Price= ",price,"=",qty*price)
        
    elif(non_veg_opt==2):
        print("shawarma......200")
        qty=int(input("Enter the total Quantity : "))
        price=int(input("Enter the Price :"))
        print("Chicken","qty=",qty,"Price= ",price,"=",qty*price)
        
        
Bill=0
def Bill(qty,price):
    global Bill
    Bill=Bill+(qty*price)
    
Welcome()
# Out:
# Welcome to the Taj
# press 1. for Veg
# press 2. for Non-veg
# press 3. for Bill
# press4. for exit
# 1
# Veg Dish name:
# 1. for Mix-veg
# 2. for Dal
# 3. for Rice
# 1
# Mix-veg ........250
# Enter the total Quantity : 2
# Enter the Price :250
# Mix_veg qty= 2 Price= 250 = 500
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2904\2922446860.py in <module>
#      75     Bill=Bill+(qty*price)
#      76
# ---> 77 Welcome()
#      78
#
# ~\AppData\Local\Temp\ipykernel_2904\2922446860.py in Welcome()
#       2 def Welcome():
#       3     print("Welcome to the Taj ")
# ----> 4     Menu()
#       5
#       6 def Menu ():
#
# ~\AppData\Local\Temp\ipykernel_2904\2922446860.py in Menu()
#      10     print("press4. for exit")
#      11     opt=int(input())
# ---> 12     dish(opt)
#      13
#      14 def dish(opt):
#
# ~\AppData\Local\Temp\ipykernel_2904\2922446860.py in dish(opt)
#      19         print("3. for Rice")
#      20         veg_opt=int(input())
# ---> 21         veg(veg_opt)
#      22
#      23     elif(opt==2):
#
# ~\AppData\Local\Temp\ipykernel_2904\2922446860.py in veg(veg_opt)
#      35         price=int(input("Enter the Price :"))
#      36         print("Mix_veg","qty=",qty,"Price=",price,"=",qty*price)
# ---> 37         Bill(qty,price)
#      38         Menu()
#      39
#
# ~\AppData\Local\Temp\ipykernel_2904\2922446860.py in Bill(qty, price)
#      73 def Bill(qty,price):
#      74     global Bill
# ---> 75     Bill=Bill+(qty*price)
#      76
#      77 Welcome()
#
# TypeError: unsupported operand type(s) for +: 'function' and 'int'

# %%
def sample ():
    print("Hello world ")
    
sample()

a=int(input("A = "))
b=int(input("B = "))
def sum(a,b):
    ans=a+b
    print(ans)

ans=sum(a,b)
sum()
# Out:
# Hello world
