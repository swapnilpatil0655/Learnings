# %% [markdown]
# # Lambda Functoion in Python

# %% [markdown]
# Lambda functions are small anonymous functions defined using the lambda keyword. They can have any number of arguments but only one expression. They are commonly used for short operations or as arguments to higher-order functions.

# %%
# Syntax of Lambda Function
lambda arguments: expression
# Out:
# <function __main__.<lambda>(arguments)>

# %%
def addition(a,b):
    return a+b

# %%
addition(2,3)
# Out:
# 5

# %%
addition=lambda a,b:a+b
print(type(addition))

print(addition(5,6))
# Out:
# <class 'function'>
# 11

# %%
def even(num):
    if num%2==0:
        return True

even(24)
# Out:
# True

# %%
# convert in lambda function
even1=lambda num:num%2==0
even1(12)
# Out:
# True

# %%
def addition(x,y,z):
    return x+y+z

addition(12,13,14)
# Out:
# 39

# %%
addition = lambda x,y,z:x+y+z
addition(1,2,3)
# Out:
# 6

# %% [markdown]
# ## Map()

# %%
# numbers=[1,2,3,4,5,6]

def square(number):
    return number**2

square(20)
# Out:
# 400

# %% [markdown]
# ### map()- applies a function to all items in a list

# %%
list(map(lambda x:x**2,numbers))   #map uses Lazy loding technic
# Out:
# [1, 4, 9, 16, 25, 36]
