# %% [markdown]
# # Decorator
#
# Decorator are a powerful and flexible feature in Python that allows you to modify the behavior of a function or class method. They are commonly used to add functionality to functions or methods without modifying their actual code. This lesson covers the basic of decorators, including how to create and use them.

# %%
### Function copy
### Closures
### decorators

# %% [markdown]
# ### Function copy

# %%
def welcome():
    return "Welcome to the advance Python course."

welcome()
# Out:
# 'Welcome to the advance Python course.'

# %%
wel= welcome
print(wel())
del welcome
print(wel())
# Out:
# Welcome to the advance Python course.
# Welcome to the advance Python course.

# %%
# After deleting the welcome function.
wel= welcome
print(wel())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 wel= welcome
#       2 print(wel())
#
# NameError: name 'welcome' is not defined

# %% [markdown]
# ### Closures
#
# closures nothing but method within the method

# %%
def main_welcome():
    msg="welcome"
    def sub_welcome_method():
        print("Welcome to the advance Python course")

        print("Please learn these concepts properly")
    return sub_welcome_method()

# %%
main_welcome()
# Out:
# Welcome to the advance Python course
# Please learn these concepts properly

# %%
def main_welcome():
    msg="welcome"
    def sub_welcome_method():
        print("Welcome to the advance Python course")
        print(msg)
        print("Please learn these concepts properly")
    return sub_welcome_method()

# %%
main_welcome()
# Out:
# Welcome to the advance Python course
# welcome
# Please learn these concepts properly

# %%
def main_welcome(msg):

    def sub_welcome_method():
        print("Welcome to the advance Python course")
        print(msg)
        print("Please learn these concepts properly")
    return sub_welcome_method()

# %%
main_welcome("Welcome everyone")
# Out:
# Welcome to the advance Python course
# Welcome everyone
# Please learn these concepts properly

# %%
def main_welcome(func):
    msg="welcome"
    def sub_welcome_method():
        print("Welcome to the advance Python course")
        func()
        print("Please learn these concepts properly")
    return sub_welcome_method()

# %%
main_welcome(print)  # print is a inbuilt function to print anything.
# Out:
# Welcome to the advance Python course
#
# Please learn these concepts properly

# %%
def main_welcome(func):
    msg="welcome"
    def sub_welcome_method():
        print("Welcome to the advance Python course")
        func("Welcome everyone to this tutorial")
        print("Please learn these concepts properly")
    return sub_welcome_method()

# %%
main_welcome(print)
# Out:
# Welcome to the advance Python course
# Welcome everyone to this tutorial
# Please learn these concepts properly

# %%
def main_welcome(func,lst):
    msg="welcome"
    def sub_welcome_method():
        print("Welcome to the advance Python course")
        print(func(lst))
        print("Please learn these concepts properly")
    return sub_welcome_method()

# %%
main_welcome(len,[1,2,3,4,5,6])
# Out:
# Welcome to the advance Python course
# 6
# Please learn these concepts properly

# %%
len([1,2,3,4,5,6])
# Out:
# 6

# %% [markdown]
# ### Decorators

# %%
def main_welcome(func):
    msg="welcome"
    def sub_welcome_method():
        print("Welcome to the advance Python course")
        func()
        print("Please learn these concepts properly")
    return sub_welcome_method()

# %%
def course_introduction():
    print("This is a advance Python course")

course_introduction()
# Out:
# This is a advance Python course

# %%
main_welcome(course_introduction)
# Out:
# Welcome to the advance Python course
# This is a advance Python course
# Please learn these concepts properly

# %%
@main_welcome
def course_introduction():
    print("This is an advance Python course.")
# Out:
# Welcome to the advance Python course
# This is an advance Python course.
# Please learn these concepts properly

# %%
## Decorator

def my_decorator(func):
    def wrapper():
        print("Something is happening before the function is called.")
        func()
        print("Something is happening after the function is called.")
    return wrapper

# %%
@my_decorator
def say_hello():
    print("Hello!")

# %%
say_hello()
# Out:
# Something is happening before the function is called.
# Hello!
# Something is happening after the function is called.

# %%
## Decorators with arguments.
def repeat(n):
    def decorator(func):
        def wrapper(*args, **kwargs):
            for _ in range(n):
                func(*args, **kwargs)
        return wrapper
    return decorator

# %%
@repeat(3)
def say_hello():
    print("Hello! ")

# %%
say_hello()
# Out:
# Hello!
# Hello!
# Hello!

# %% [markdown]
# ### Conclusion
#
# Decorators are a powerful tool in Python for extending and modifying the behavior of functions and methods. They provide a clean and readable way to add functionality such as logging, timing, access control, and more without changing the original code. Understanding and using decorators effectively can significantly enhance your Python programming skills.
