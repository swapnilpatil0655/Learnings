# %% [markdown]
# # Data Manipulation and Analysis with Pandas

# %% [markdown]
# Data manipulation and analysis are key tasks in any data science or data analysis project. Pandas provides a wide range of functions for data manipulation and analysis, making it easier to clean, transform, and extract insights form data. In this lesson, we will cover various data manipulation and analysis techniques using Pandas.

# %%
import pandas as pd

# %%
df = pd.read_csv('data (1).csv')

# %%
## Fetch first 5 rows.
df.head(5)
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
df.tail(5)
# Out:
#           Date Category  Value   Product  Sales Region
# 45  2023-02-15        B   99.0  Product2  599.0   West
# 46  2023-02-16        B    6.0  Product1  938.0  South
# 47  2023-02-17        B   69.0  Product3  143.0   West
# 48  2023-02-18        C   65.0  Product3  182.0  North
# 49  2023-02-19        C   11.0  Product3  708.0  North

# %%
df.describe()
# Out:
#            Value       Sales
# count  47.000000   46.000000
# mean   51.744681  557.130435
# std    29.050532  274.598584
# min     2.000000  108.000000
# 25%    27.500000  339.000000
# 50%    54.000000  591.500000
# 75%    70.000000  767.500000
# max    99.000000  992.000000

# %%
df.dtypes
# Out:
# Date         object
# Category     object
# Value       float64
# Product      object
# Sales       float64
# Region       object
# dtype: object

# %% [markdown]
# ####  Handling missing values

# %%
df.isnull()
# Out:
#      Date  Category  Value  Product  Sales  Region
# 0   False     False  False    False  False   False
# 1   False     False  False    False  False   False
# 2   False     False  False    False  False   False
# 3   False     False  False    False  False   False
# 4   False     False  False    False  False   False
# 5   False     False  False    False  False   False
# 6   False     False  False    False  False   False
# 7   False     False  False    False  False   False
# 8   False     False  False    False  False   False
# 9   False     False  False    False  False   False
# 10  False     False  False    False  False   False
# 11  False     False  False    False   True   False
# 12  False     False  False    False  False   False
# 13  False     False  False    False  False   False
# 14  False     False  False    False  False   False
# 15  False     False   True    False  False   False
# 16  False     False  False    False  False   False
# ...

# %%
df[df.isnull().any(axis=1)] 
# axis is 0 for rows and 1 for columns. Here we are checking for any null values in the rows, so we use axis=1.
# Out:
#           Date Category  Value   Product  Sales Region
# 11  2023-01-12        B   60.0  Product2    NaN   West
# 15  2023-01-16        C    NaN  Product1  895.0  North
# 17  2023-01-18        C    NaN  Product1  108.0   West
# 28  2023-01-29        B    NaN  Product3  617.0  North
# 33  2023-02-03        C   27.0  Product3    NaN   East
# 35  2023-02-05        B   60.0  Product2    NaN   West
# 37  2023-02-07        C    2.0  Product1    NaN  North

# %%
df.isnull().sum()
# Out:
# Date        0
# Category    0
# Value       3
# Product     0
# Sales       4
# Region      0
# dtype: int64

# %%
df.fillna(0, inplace=True)
df
# Out:
#           Date Category  Value   Product  Sales Region
# 0   2023-01-01        A   28.0  Product1  754.0   East
# 1   2023-01-02        B   39.0  Product3  110.0  North
# 2   2023-01-03        C   32.0  Product2  398.0   East
# 3   2023-01-04        B    8.0  Product1  522.0   East
# 4   2023-01-05        B   26.0  Product3  869.0  North
# 5   2023-01-06        B   54.0  Product3  192.0   West
# 6   2023-01-07        A   16.0  Product1  936.0   East
# 7   2023-01-08        C   89.0  Product1  488.0   West
# 8   2023-01-09        C   37.0  Product3  772.0   West
# 9   2023-01-10        A   22.0  Product2  834.0   West
# 10  2023-01-11        B    7.0  Product1  842.0  North
# 11  2023-01-12        B   60.0  Product2    0.0   West
# 12  2023-01-13        A   70.0  Product3  628.0  South
# 13  2023-01-14        A   69.0  Product1  423.0   East
# 14  2023-01-15        A   47.0  Product2  893.0   West
# 15  2023-01-16        C    0.0  Product1  895.0  North
# ...

# %% [markdown]
# we already know that missing values can cause problems in data analysis and modeling. Pandas provides several functions to handle missing values, such as `isnull()`, `dropna()`, and `fillna()`.

# %% [markdown]
# we already fill na with 0 so below fillna programe line will not work as there is no na value in the dataset. So we will reload the dataset to get the original data with na values.

# %%
df.isnull().sum()
# Out:
# Date        0
# Category    0
# Value       0
# Product     0
# Sales       0
# Region      0
# dtype: int64

# %%
### filling mussing values with mean of the column.
df.fillna(df.mean(), inplace=True)
df
# Out:
# C:\Users\swapn\AppData\Local\Temp\ipykernel_8400\3901630617.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)
#           Date Category      Value   Product       Sales Region
# 0   2023-01-01        A  28.000000  Product1  754.000000   East
# 1   2023-01-02        B  39.000000  Product3  110.000000  North
# 2   2023-01-03        C  32.000000  Product2  398.000000   East
# 3   2023-01-04        B   8.000000  Product1  522.000000   East
# 4   2023-01-05        B  26.000000  Product3  869.000000  North
# 5   2023-01-06        B  54.000000  Product3  192.000000   West
# 6   2023-01-07        A  16.000000  Product1  936.000000   East
# 7   2023-01-08        C  89.000000  Product1  488.000000   West
# ...

# %%
df = pd.read_csv('data (1).csv')

# %%
df.isnull().sum()
# Out:
# Date        0
# Category    0
# Value       3
# Product     0
# Sales       4
# Region      0
# dtype: int64

# %%
# after the reload the dataset 
### filling mussing values with mean of the column.
df.fillna(df.mean(), inplace=True)
df
# Out:
# C:\Users\swapn\AppData\Local\Temp\ipykernel_8400\745431150.py:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)
#           Date Category      Value   Product       Sales Region
# 0   2023-01-01        A  28.000000  Product1  754.000000   East
# 1   2023-01-02        B  39.000000  Product3  110.000000  North
# 2   2023-01-03        C  32.000000  Product2  398.000000   East
# 3   2023-01-04        B   8.000000  Product1  522.000000   East
# 4   2023-01-05        B  26.000000  Product3  869.000000  North
# 5   2023-01-06        B  54.000000  Product3  192.000000   West
# 6   2023-01-07        A  16.000000  Product1  936.000000   East
# 7   2023-01-08        C  89.000000  Product1  488.000000   West
# ...

# %%
## Handling missing values
df.isnull().any() # for any missing value for column this will show True.
# Out:
# Date        False
# Category    False
# Value       False
# Product     False
# Sales       False
# Region      False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Date        0
# Category    0
# Value       0
# Product     0
# Sales       0
# Region      0
# dtype: int64

# %%
df = pd.read_csv('data (1).csv')

# %%
df.isnull().sum()
# Out:
# Date        0
# Category    0
# Value       3
# Product     0
# Sales       4
# Region      0
# dtype: int64

# %%
df_filled = df.fillna(0)

# %%
### filling missing values with the mean of the column
df['Sales_full_NA'] = df['Sales'].fillna(df['Sales'].mean())
df
# Out:
#           Date Category  Value   Product  Sales Region  Sales_full_NA
# 0   2023-01-01        A   28.0  Product1  754.0   East     754.000000
# 1   2023-01-02        B   39.0  Product3  110.0  North     110.000000
# 2   2023-01-03        C   32.0  Product2  398.0   East     398.000000
# 3   2023-01-04        B    8.0  Product1  522.0   East     522.000000
# 4   2023-01-05        B   26.0  Product3  869.0  North     869.000000
# 5   2023-01-06        B   54.0  Product3  192.0   West     192.000000
# 6   2023-01-07        A   16.0  Product1  936.0   East     936.000000
# 7   2023-01-08        C   89.0  Product1  488.0   West     488.000000
# 8   2023-01-09        C   37.0  Product3  772.0   West     772.000000
# 9   2023-01-10        A   22.0  Product2  834.0   West     834.000000
# 10  2023-01-11        B    7.0  Product1  842.0  North     842.000000
# 11  2023-01-12        B   60.0  Product2    NaN   West     557.130435
# ...

# %%
df.dtypes
# Out:
# Date              object
# Category          object
# Value            float64
# Product           object
# Sales            float64
# Region            object
# Sales_full_NA    float64
# dtype: object

# %% [markdown]
# #### Renaming columns

# %%
df = df.rename(columns = {'Date':'Sales Date'})
df.head(5)
# Out:
#    Sales Date Category  Value   Product  Sales Region  Sales_full_NA
# 0  2023-01-01        A   28.0  Product1  754.0   East          754.0
# 1  2023-01-02        B   39.0  Product3  110.0  North          110.0
# 2  2023-01-03        C   32.0  Product2  398.0   East          398.0
# 3  2023-01-04        B    8.0  Product1  522.0   East          522.0
# 4  2023-01-05        B   26.0  Product3  869.0  North          869.0

# %% [markdown]
# #### Change datatype

# %%
df['Value_new'] = df['Value'].astype(float)
df.head(5)
# Out:
#    Sales Date Category  Value   Product  Sales Region  Sales_full_NA  \
# 0  2023-01-01        A   28.0  Product1  754.0   East          754.0
# 1  2023-01-02        B   39.0  Product3  110.0  North          110.0
# 2  2023-01-03        C   32.0  Product2  398.0   East          398.0
# 3  2023-01-04        B    8.0  Product1  522.0   East          522.0
# 4  2023-01-05        B   26.0  Product3  869.0  North          869.0
#
#    Value_new
# 0       28.0
# 1       39.0
# 2       32.0
# 3        8.0
# 4       26.0

# %%
df['Value_new'] = df['Value'].fillna(df['Value'].mean()).astype(int)
df.head(5)
# Out:
#    Sales Date Category  Value   Product  Sales Region  Sales_full_NA  \
# 0  2023-01-01        A   28.0  Product1  754.0   East          754.0
# 1  2023-01-02        B   39.0  Product3  110.0  North          110.0
# 2  2023-01-03        C   32.0  Product2  398.0   East          398.0
# 3  2023-01-04        B    8.0  Product1  522.0   East          522.0
# 4  2023-01-05        B   26.0  Product3  869.0  North          869.0
#
#    Value_new
# 0         28
# 1         39
# 2         32
# 3          8
# 4         26

# %%
df['New Value']=df['Value'].apply(lambda x:x*2)
df.head()
# Out:
#    Sales Date Category  Value   Product  Sales Region  Sales_full_NA  \
# 0  2023-01-01        A   28.0  Product1  754.0   East          754.0
# 1  2023-01-02        B   39.0  Product3  110.0  North          110.0
# 2  2023-01-03        C   32.0  Product2  398.0   East          398.0
# 3  2023-01-04        B    8.0  Product1  522.0   East          522.0
# 4  2023-01-05        B   26.0  Product3  869.0  North          869.0
#
#    Value_new  New Value
# 0         28       56.0
# 1         39       78.0
# 2         32       64.0
# 3          8       16.0
# 4         26       52.0

# %% [markdown]
# #### Data Aggregating and Grouping

# %%
df.head()
# Out:
#    Sales Date Category  Value   Product  Sales Region  Sales_full_NA  \
# 0  2023-01-01        A   28.0  Product1  754.0   East          754.0
# 1  2023-01-02        B   39.0  Product3  110.0  North          110.0
# 2  2023-01-03        C   32.0  Product2  398.0   East          398.0
# 3  2023-01-04        B    8.0  Product1  522.0   East          522.0
# 4  2023-01-05        B   26.0  Product3  869.0  North          869.0
#
#    Value_new  New Value
# 0         28       56.0
# 1         39       78.0
# 2         32       64.0
# 3          8       16.0
# 4         26       52.0

# %%
grouped_mean = df.groupby('Product')['Value'].mean()
print(grouped_mean)
# Out:
# Product
# Product1    46.214286
# Product2    52.800000
# Product3    55.166667
# Name: Value, dtype: float64

# %%
grouped_sum = df.groupby(['Product','Region'])['Value'].sum()
print(grouped_sum)
# Out:
# Product   Region
# Product1  East      292.0
#           North       9.0
#           South     100.0
#           West      246.0
# Product2  East       56.0
#           North     127.0
#           South     181.0
#           West      428.0
# Product3  East      202.0
#           North     203.0
#           South     215.0
#           West      373.0
# Name: Value, dtype: float64

# %%
df.groupby(['Product','Region'])['Value'].mean()
# Out:
# Product   Region
# Product1  East      41.714286
#           North      4.500000
#           South     50.000000
#           West      82.000000
# Product2  East      28.000000
#           North     63.500000
#           South     60.333333
#           West      53.500000
# Product3  East      50.500000
#           North     40.600000
#           South     71.666667
#           West      62.166667
# Name: Value, dtype: float64

# %% [markdown]
# #### Aggregate multiple functions

# %%
grouped_agg=df.groupby('Region')['Value'].agg(['mean','sum','count'])
grouped_agg
# Out:
#              mean     sum  count
# Region
# East    42.307692   550.0     13
# North   37.666667   339.0      9
# South   62.000000   496.0      8
# West    61.588235  1047.0     17

# %% [markdown]
# #### Merging and Joining DataFrame

# %%
# Create a sample DataFrame
df1 = pd.DataFrame({'Key':['A','B','C'],'Value1':[1,2,3]})
df2 = pd.DataFrame({'Key':['A','B','D'],'Value2':[4,5,6]})

# %%
df1
# Out:
#   Key  Value1
# 0   A       1
# 1   B       2
# 2   c       3

# %%
df2
# Out:
#   Key  Value2
# 0   A       4
# 1   B       5
# 2   D       6

# %%
## Merging DataFrames on the 'Key' column
pd.merge(df1,df2,on="Key",how= 'inner')
# Out:
#   Key  Value1  Value2
# 0   A       1       4
# 1   B       2       5

# %%
pd.merge(df1,df2,on="Key",how= 'outer')
# Out:
#   Key  Value1  Value2
# 0   A     1.0     4.0
# 1   B     2.0     5.0
# 2   C     3.0     NaN
# 3   D     NaN     6.0

# %%
pd.merge(df1,df2,on="Key",how= 'left')
# Out:
#   Key  Value1  Value2
# 0   A       1     4.0
# 1   B       2     5.0
# 2   C       3     NaN

# %%
pd.merge(df1,df2,on="Key",how= 'right')
# Out:
#   Key  Value1  Value2
# 0   A     1.0       4
# 1   B     2.0       5
# 2   D     NaN       6
