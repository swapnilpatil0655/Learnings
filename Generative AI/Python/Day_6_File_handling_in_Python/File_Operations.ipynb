# %% [markdown]
# # File Operation - Read And Write Files
#
# File handling is a crucial part of any programming language. Python provides built-in functions and method to read from and write to files, both text and binery. This lesson will cover the basic of file handling, including reading and writing text files and binary files

# %%
### Read a whole file

with open ('example.txt','r') as file:
    content= file.read()
    print(content)
# Out:
# Hello, Good Morning!
# how are you ?
# I am Good, welcome to python learning series.

# %%
### Read a file line by line

with open ('example.txt','r') as file:
    for line in file:
        print(line.strip()) #.strip() removes the newline character.
# Out:
# Hello world!
# /n is for new line.
# Append operating is for adding the new line without overwriting.

# %%
## Writing a file(Overwriting)

with open ('example.txt','w') as file:
    file.write("Hello world!\n") # \n is for new line
    file.write('/n is for new line.\n')

# %%
 ## Write a file (without Overwriting)
 with open ('example.txt','a') as file:
    file.write("Append operating is for adding the new line without overwriting.\n")

# %%
## Writing a list of lines to a file.

lines = ['First line \n','Second line \n','Third line\n']

with open ('example.txt','a') as file:
    file.writelines(lines)

# %%
## Binary Files . .bin is the extension of the binary file.
data = b'\x00\x01\x02\x03\x04'
with open('example.bin','wb') as bin:
    bin.write(data)

# %%
# Rading a binary file
data = b'\x00\x01\x02\x03\x04'
with open('example.bin','rb') as bin:
    content=bin.read()
    print(content)
# Out:
# b'\x00\x01\x02\x03\x04'

# %%
## Read the content from source text source text file and write to a destination text file
# Copying a text file

with open ('example.txt','r') as source_file:
    content = source_file.read()

with open('destination.txt','w') as destination_file:
    destination_file.write(content)

# %%
# Read a text file and count the number of lines, words, and characters.
# Counting lines, words, and characters in text file.

def count_text_file(file_path):
    with open(file_path,'r') as file:
        line = file.readlines()
        line_count = len(line)
        word_count = sum(len(line.split()) for line in line)
        char_count = sum(len(line) for line in line)
        return line_count,word_count,char_count

file_path = 'example.txt'
line,words, characters = count_text_file(file_path)
print(f"Lines:{line},Words:{words},characters:{characters}")
# Out:
# Lines:9,Words:29,characters:170

# %% [markdown]
# The w+ mode in Python is used to open a file for both reading and writing. If the file does not exist, it will be created. If the file exists, its content is truncated(i.e., the file is overwriten)

# %%
### Writing and then reading a file

with open ('example.txt','w+') as file:
    file.write("Hello World!\n")
    file.write("This is a new line \n")

    ## move the file cursor to the beging
    file.seek(0)

    ## Read the content of the file
    content = file.read()
    print(content)
# Out:
# Hello World!
# This is a new line

# %% [markdown]
# # Create a new directory

# %%
import os

# %%
new_directory = "package"
os.mkdir(new_directory)
print(f"Directory '{new_directory}' created")
# Out:
# Directory 'package' created

# %%
## Listing files and directorys

items=os.listdir('.')
print(items)
# Out:
# ['destination.txt', 'example.bin', 'example.txt', 'File_Operations.ipynb', 'package']

# %%
### joining path

dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(dir_name,file_path)
print(full_path)
# Out:
# folder\example.txt

# %%
dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(os.getcwd(),dir_name,file_path)
print(full_path)
# Out:
# e:\git_hub\Learnings\Generative AI\Python\Day_6_File_handling_in_Python\folder\example.txt

# %%
path = 'example.txt'
if os.path.exists(path):
    print(f"The path '{path}' exists")
else:
    print(f"The path '{path}' does not exists")
# Out:
# The path 'example.txt' exists

# %%
# Checking if a path is a file or directory

import os

path = 'example.txt'
if os.path.isfile(path):
    print(f"The path '{path}' is a file.")
elif os.path.isdir(path):
    print(f"The path '{path}' is a directory.")
else:
    print(f"The path '{path}' is neither a file not a directory.")
# Out:
# The path 'example.txt' is a file.

# %%
## Getting the aboslute path

relative_path = 'example.txt'
absolute_path = os.path.abspath(relative_path)
print(absolute_path)
# Out:
# e:\git_hub\Learnings\Generative AI\Python\Day_6_File_handling_in_Python\example.txt
