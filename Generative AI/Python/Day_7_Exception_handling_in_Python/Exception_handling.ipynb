# %% [markdown]
# ### Understanding Exception
#
# Exception handling in Python allows you to handle errors gracefully and take corrective action without stopping the execution of the program. This lesson will cover the basics of exceptions, including how to use `try`, `except`, `else`,and `finally` blocks

# %% [markdown]
# ### What Are Exceptions
#
# Exception are events that disrupt the normal flow of a program. They occur when and error is encountered during program execution exception include.
#
# - `ZeroDivisionError`: Dividing by zero.
# - `FileNotFoundError`: File not found.
# - `ValueError`: Invalid value.
# - `TypeError`: Invalid type.

# %%
a = b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a = b
#
# NameError: name 'b' is not defined

# %%
## Exception try,except block

try:
    a = b
except:
    print("The variable has not been assigned")
# Out:
# The variable has not been assigned

# %%
## Exception try,except block

try:
    a = b
except NameError as na:
    print(na)
# Out:
# name 'b' is not defined

# %%
try:
    result =1/0
except ZeroDivisionError as ze:
    print(ze)
    print("Please enter the denominator greater that 0")
# Out:
# division by zero
# Please enter the denominator greater that 0

# %%
try:
    result =1/2
    a=b
except ZeroDivisionError as ze:
    print(ze)
    print("Please enter the denominator greater that 0")
except Exception as ex:   #Exception is a parent exception we can use this for all exception.a
    print(ex)
# Out:
# name 'b' is not defined

# %%
try:
    num = int(input("Enter a number: "))
    result=10/num
except ValueError:
    print("This is not valid number")
except ZeroDivisionError:
    print("enter denominator greater than 0")

# %%
try:
    num = int(input("Enter a number: "))
    result=10/num
except ValueError:
    print("This is not valid number")
except ZeroDivisionError:
    print("enter denominator greater than 0")
except Exception as ex:   #Exception is a parent exception we can use this for all exception.a
    print(ex)

else:
    print(f"Result : {result}")
# Out:
# Result : 0.3125

# %%
## Try,except,else and finally 

try:
    num = int(input("Enter a number: "))
    result=10/num
except ValueError:
    print("This is not valid number")
except ZeroDivisionError:
    print("enter denominator greater than 0")
except Exception as ex:   #Exception is a parent exception we can use this for all exception.a
    print(ex)

else:
    print(f"Result : {result}")

finally:
    print("Execution complete.")
# Out:
# enter denominator greater than 0
# Execution complete.

# %%
## File handling and exception handling

try:
    file = open('example1.txt','r')
    content = file.read()
    print(content)

except FileNotFoundError:
    print("The file does not exists")

except Exception as ex:
    print(ex)

finally:
    if 'file' in locals() or not file.closed():
        file.closed
        print('file close')
# Out:
# Hi
# file close
