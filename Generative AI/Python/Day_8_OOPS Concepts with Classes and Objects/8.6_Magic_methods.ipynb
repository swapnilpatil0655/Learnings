# %% [markdown]
# ### Magic Methods
#
# Magic methods in Python, also known as dunder methods(Double underscore methods), are special methods that start and end with double underscores. These methods enable you to `define the behavior of objects for built-in operations, such as arithmetic operations, comparisons, and more`.

# %% [markdown]
# #### Magic methods
#
# Magic methods are predefined methods in Python that you can override to chage the behavior of your objects. Some common methods include:
# - `__init__`: initializes a new instance of a class.
# - `__str__`: returns a string representation of an object.
# - `__rerpr__`: Return an official string representation of an object.
# - `__len__`: Returns the length of an objet.
# - `__getitem__`: Gets an item from a container.
# - `__setitem__`: Sets an item in a container.

# %%
class Person:
    pass

person = Person()

dir (person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
## Basic Methods

class Person:
    def __init__(self,name,age):
        self.name = name
        self.age  = age

    def __str__ (self):
        return f"{self.name}, {self.age} years old"

    def __repr__ (self):
        return f"Person(name={self.name},age ={self.age})"

person = Person('Swapnil',30)

print(person)
print(repr(person))
# Out:
# Swapnil, 30 years old
# Person(name=Swapnil,age =30)
