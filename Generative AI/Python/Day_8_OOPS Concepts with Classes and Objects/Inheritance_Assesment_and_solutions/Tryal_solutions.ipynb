# %% [markdown]
# ### Module: Inheritance Assignment
# Lesson: Single and Multiple Inheritance

# %% [markdown]
# Assignment 1:<br> Single Inheritance Basic
# Create a base class named `Animal` with attributes `name` and `species`. Create a derived class named `Dog` that inherits from `Animal` and adds and attribute `breed`. Create an object of the `Dog` class and print its attributes.

# %%
class Animal:
    def __init__(self,name,species):
        self.name = name
        self.species = species


class Dog(Animal):
    def __init__ (self,name,species,breed):
        super().__init__(name,species)
        self.breed = breed

dog = Dog('Buddy','canine','Golden Retriever')
print(dog.name,dog.species,dog.breed)
# Out:
# Buddy canine Golden Retriever

# %% [markdown]
# Assignment 2:<br>
# In the `Dog` class, override the `__str__` method to return a string representation of the object. Create and object of the class and print it.

# %%
class Dog(Animal):
    def __init__ (self,name,species,breed):
        super().__init__(name,species)
        self.breed = breed

    def __str__(self):
        return f"Dog(Name:{self.name}, Species:{self.species}, Breed:{self.breed})"

dog = Dog('Buddy','canine','Golden Retriever')
print(dog)
# Out:
# Dog(Name:Buddy, Species:canine, Breed:Golden Retriever)

# %% [markdown]
# Assignment 3:<br>
# In the `Dog` class, add a method named `bark` that prints a barking sound. Create and object of the class and call the method.

# %%
class Dog(Animal):
    def __init__ (self,name,species,breed):
        super().__init__(name,species)
        self.breed = breed

    def bark(self):
        print(f"{self.name} says Woof!")

dog = Dog('Buddy','canine','Golden Retriever')

dog.bark()
# Out:
# Buddy says Woof!
